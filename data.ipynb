# %% [markdown]
# # Accenture Data Analysis for Social Buzz

# %% [markdown]
# ### Import Necessary Libraries

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load Necessary Files:
#
# #### 1. Load Content File:

# %%
Content_df= pd.read_csv("Content.csv")
Content_df
# Out:
#      Unnamed: 0                            Content ID  \
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180
# ..          ...                                   ...
# 995         995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999         999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type         Category  \
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo   healthy eating
# ...

# %% [markdown]
# #### Cleaning and Transform the Data:

# %%
Content_df = Content_df.drop(columns=["URL", "Unnamed: 0"])
Content_df
# Out:
#                                Content ID  \
# 0    97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1    9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2    230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3    356fff80-da4d-4785-9f43-bc1261031dc6
# 4    01ab84dd-6364-4236-abbb-3f237db77180
# ..                                    ...
# 995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type         Category
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo   healthy eating
# 3    9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo       technology
# 4    e206e31b-5f85-4964-b6ea-d7ee5324def1  video             food
# ...

# %%
Content_df['Category']=Content_df['Category'].str.replace('"','')
Content_df['Category']=Content_df['Category'].str.lower()
Content_df
# Out:
#                                Content ID  \
# 0    97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1    9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2    230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3    356fff80-da4d-4785-9f43-bc1261031dc6
# 4    01ab84dd-6364-4236-abbb-3f237db77180
# ..                                    ...
# 995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type         Category
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo   healthy eating
# 3    9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo       technology
# 4    e206e31b-5f85-4964-b6ea-d7ee5324def1  video             food
# ...

# %%
df= Content_df["Category"].isnull()
df
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Category, Length: 1000, dtype: bool

# %%
Content_df["Content Type"] = Content_df["Type"]
Content_df = Content_df.drop(columns="Type")
Content_df
# Out:
#                                Content ID  \
# 0    97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1    9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2    230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3    356fff80-da4d-4785-9f43-bc1261031dc6
# 4    01ab84dd-6364-4236-abbb-3f237db77180
# ..                                    ...
# 995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID         Category Content Type
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31         studying        photo
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43   healthy eating        photo
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4   healthy eating        photo
# 3    9fb4ce88-fac1-406c-8544-1a899cee7aaf       technology        photo
# 4    e206e31b-5f85-4964-b6ea-d7ee5324def1             food        video
# ...

# %% [markdown]
# #### 2. Load Reactions File:

# %%
Reactions_df= pd.read_csv("Reactions.csv")
Reactions_df
# Out:
#        Unnamed: 0                            Content ID  \
# 0               0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1               1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2               2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3               3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4               4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...           ...                                   ...
# 25548       25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549       25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550       25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551       25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552       25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type         Datetime
# 0                                       NaN         NaN  4/22/2021 15:17
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust   11/7/2020 9:43
# ...

# %% [markdown]
# #### Cleaning and Transform the Data:

# %%
Reactions_df=Reactions_df.drop(columns="Unnamed: 0")
Reactions_df
# Out:
#                                  Content ID  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type         Datetime
# 0                                       NaN         NaN  4/22/2021 15:17
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust   11/7/2020 9:43
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     dislike  6/17/2021 12:22
# 3      163daa38-8b77-48c9-9af6-37a6c1447ac2      scared   4/18/2021 5:13
# ...

# %%
Reactions_df=Reactions_df.drop_duplicates()
Reactions_df
# Out:
#                                  Content ID  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type         Datetime
# 0                                       NaN         NaN  4/22/2021 15:17
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust   11/7/2020 9:43
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     dislike  6/17/2021 12:22
# 3      163daa38-8b77-48c9-9af6-37a6c1447ac2      scared   4/18/2021 5:13
# ...

# %%
Reactions_df["reactionnull"] = Reactions_df["Type"].isnull()
Reactions_df["usernull"]= Reactions_df["User ID"].isnull()
Reactions_df
# Out:
#                                  Content ID  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type         Datetime  \
# 0                                       NaN         NaN  4/22/2021 15:17
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust   11/7/2020 9:43
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     dislike  6/17/2021 12:22
# 3      163daa38-8b77-48c9-9af6-37a6c1447ac2      scared   4/18/2021 5:13
# ...

# %%
Reactions_df=Reactions_df.loc[(Reactions_df["reactionnull"]==False) & (Reactions_df["usernull"]==False)]
Reactions_df
# Out:
#                                  Content ID  \
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 5      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 25547  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type         Datetime  \
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust   11/7/2020 9:43
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     dislike  6/17/2021 12:22
# 3      163daa38-8b77-48c9-9af6-37a6c1447ac2      scared   4/18/2021 5:13
# 4      34e8add9-0206-47fd-a501-037b994650a2     disgust   1/6/2021 19:13
# ...

# %%
Reactions_df=Reactions_df.drop(columns=["usernull","reactionnull"])
Reactions_df
# Out:
#                                  Content ID  \
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 5      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 25547  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type         Datetime
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust   11/7/2020 9:43
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     dislike  6/17/2021 12:22
# 3      163daa38-8b77-48c9-9af6-37a6c1447ac2      scared   4/18/2021 5:13
# 4      34e8add9-0206-47fd-a501-037b994650a2     disgust   1/6/2021 19:13
# ...

# %% [markdown]
# #### 3.Load Reaction Types file:

# %%
Reactiontype_df= pd.read_csv("ReactionTypes.csv")
Reactiontype_df
# Out:
#     Unnamed: 0         Type Sentiment  Score
# 0            0        heart  positive     60
# 1            1         want  positive     70
# 2            2      disgust  negative      0
# 3            3         hate  negative      5
# 4            4   interested  positive     30
# 5            5  indifferent   neutral     20
# 6            6         love  positive     65
# 7            7   super love  positive     75
# 8            8      cherish  positive     70
# 9            9        adore  positive     72
# 10          10         like  positive     50
# 11          11      dislike  negative     10
# 12          12    intrigued  positive     45
# 13          13      peeking   neutral     35
# 14          14       scared  negative     15
# 15          15      worried  negative     12

# %% [markdown]
# #### Cleaning and Transform the Data:

# %%
Reactiontype_df=Reactiontype_df.drop(columns="Unnamed: 0")
Reactiontype_df=Reactiontype_df.drop_duplicates()
Reactiontype_df
# Out:
#            Type Sentiment  Score
# 0         heart  positive     60
# 1          want  positive     70
# 2       disgust  negative      0
# 3          hate  negative      5
# 4    interested  positive     30
# 5   indifferent   neutral     20
# 6          love  positive     65
# 7    super love  positive     75
# 8       cherish  positive     70
# 9         adore  positive     72
# 10         like  positive     50
# 11      dislike  negative     10
# 12    intrigued  positive     45
# 13      peeking   neutral     35
# 14       scared  negative     15
# 15      worried  negative     12

# %% [markdown]
# ### Join The Files:

# %%
First_df=Content_df.merge(Reactions_df,on="Content ID",how="inner")
First_df
# Out:
#                                  Content ID  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 22529  75d6b589-7fae-4a6d-b0d0-752845150e56
# 22530  75d6b589-7fae-4a6d-b0d0-752845150e56
# 22531  75d6b589-7fae-4a6d-b0d0-752845150e56
# 22532  75d6b589-7fae-4a6d-b0d0-752845150e56
# 22533  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID_x    Category Content Type  \
# 0      8d3cd87d-8a31-4935-9a4f-b319bfe05f31    studying        photo
# 1      8d3cd87d-8a31-4935-9a4f-b319bfe05f31    studying        photo
# 2      8d3cd87d-8a31-4935-9a4f-b319bfe05f31    studying        photo
# 3      8d3cd87d-8a31-4935-9a4f-b319bfe05f31    studying        photo
# 4      8d3cd87d-8a31-4935-9a4f-b319bfe05f31    studying        photo
# ...

# %%
FinalData_df=First_df.merge(Reactiontype_df,on="Type",how="inner")
FinalData_df
# Out:
#                                  Content ID  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 22529  75d6b589-7fae-4a6d-b0d0-752845150e56
# 22530  75d6b589-7fae-4a6d-b0d0-752845150e56
# 22531  75d6b589-7fae-4a6d-b0d0-752845150e56
# 22532  75d6b589-7fae-4a6d-b0d0-752845150e56
# 22533  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID_x    Category Content Type  \
# 0      8d3cd87d-8a31-4935-9a4f-b319bfe05f31    studying        photo
# 1      8d3cd87d-8a31-4935-9a4f-b319bfe05f31    studying        photo
# 2      8d3cd87d-8a31-4935-9a4f-b319bfe05f31    studying        photo
# 3      8d3cd87d-8a31-4935-9a4f-b319bfe05f31    studying        photo
# 4      8d3cd87d-8a31-4935-9a4f-b319bfe05f31    studying        photo
# ...

# %% [markdown]
# #### Cleaning the Joined Data:

# %%
FinalData_df=FinalData_df.drop(columns=["User ID_x","User ID_y"])
FinalData_df
# Out:
#                                  Content ID    Category Content Type  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2    studying        photo
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2    studying        photo
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2    studying        photo
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2    studying        photo
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2    studying        photo
# ...                                     ...         ...          ...
# 22529  75d6b589-7fae-4a6d-b0d0-752845150e56  technology        audio
# 22530  75d6b589-7fae-4a6d-b0d0-752845150e56  technology        audio
# 22531  75d6b589-7fae-4a6d-b0d0-752845150e56  technology        audio
# 22532  75d6b589-7fae-4a6d-b0d0-752845150e56  technology        audio
# 22533  75d6b589-7fae-4a6d-b0d0-752845150e56  technology        audio
#
#              Type         Datetime Sentiment  Score
# 0         disgust   11/7/2020 9:43  negative      0
# ...

# %% [markdown]
# ### Export Final Data Frame into CSV:

# %%
FinalData_df.to_csv("FinalData.csv", index=False)

# %% [markdown]
# ### Load Final Data File:

# %%
FinalData_df
# Out:
#                                  Content ID    Category Content Type  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2    studying        photo
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2    studying        photo
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2    studying        photo
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2    studying        photo
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2    studying        photo
# ...                                     ...         ...          ...
# 22529  75d6b589-7fae-4a6d-b0d0-752845150e56  technology        audio
# 22530  75d6b589-7fae-4a6d-b0d0-752845150e56  technology        audio
# 22531  75d6b589-7fae-4a6d-b0d0-752845150e56  technology        audio
# 22532  75d6b589-7fae-4a6d-b0d0-752845150e56  technology        audio
# 22533  75d6b589-7fae-4a6d-b0d0-752845150e56  technology        audio
#
#              Type         Datetime Sentiment  Score
# 0         disgust   11/7/2020 9:43  negative      0
# ...

# %% [markdown]
# #### Extract and Visualize Top Content Type According to the Score:

# %%
ndf = FinalData_df.groupby("Content Type").agg(Max_score= ("Score", sum))
ndf =ndf.reset_index()
ndf.sort_values(by="Max_score", ascending=False)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15628\885594741.py:1: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   ndf = FinalData_df.groupby("Content Type").agg(Max_score= ("Score", sum))
#   Content Type  Max_score
# 2        photo     241090
# 3        video     225559
# 0          GIF     218922
# 1        audio     207911

# %%
plt.bar(ndf['Content Type'],ndf['Max_score'],width=0.5)
plt.title('Content_Type by Score')
plt.xlabel('Content Type')
plt.ylabel('Score')
plt.grid()
plt.show()

# %%
plt.pie(ndf["Max_score"], labels= ndf["Content Type"], autopct='%.2f%%', explode=[0,0,0,0.1], radius=1.5)
plt.show()

# %% [markdown]
# #### Extract and Visualize Top 5 Category According to the Score:

# %%
cdf=FinalData_df.groupby("Category").agg(Max_score= ("Score", sum))
cdf =cdf.reset_index()
cdf=cdf.sort_values(by="Max_score", ascending=False)
cdf=cdf.head(5)
cdf
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15628\47887518.py:1: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   cdf=FinalData_df.groupby("Category").agg(Max_score= ("Score", sum))
#           Category  Max_score
# 0          animals      68624
# 9          science      65405
# 7   healthy eating      63138
# 12      technology      63035
# 6             food      61598

# %%
cdf.to_csv("Top5categories.csv", index=False)

# %%
plt.plot(cdf['Category'],cdf['Max_score'],linewidth=2,marker='o')
plt.title('Category by Score')
plt.xlabel('Category')
plt.ylabel('Score')
plt.grid()
plt.show()

# %% [markdown]
# #### Extract Best Months According to the Score:

# %%
FinalData_df['Datetime']=pd.to_datetime(FinalData_df['Datetime'])
FinalData_df
# Out:
#                                  Content ID    Category Content Type  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2    studying        photo
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2    studying        photo
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2    studying        photo
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2    studying        photo
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2    studying        photo
# ...                                     ...         ...          ...
# 22529  75d6b589-7fae-4a6d-b0d0-752845150e56  technology        audio
# 22530  75d6b589-7fae-4a6d-b0d0-752845150e56  technology        audio
# 22531  75d6b589-7fae-4a6d-b0d0-752845150e56  technology        audio
# 22532  75d6b589-7fae-4a6d-b0d0-752845150e56  technology        audio
# 22533  75d6b589-7fae-4a6d-b0d0-752845150e56  technology        audio
#
#              Type            Datetime Sentiment  Score
# 0         disgust 2020-11-07 09:43:00  negative      0
# ...

# %%
FinalData_df["Month"]=FinalData_df['Datetime'].dt.month_name()
FinalData_df
# Out:
#                                  Content ID    Category Content Type  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2    studying        photo
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2    studying        photo
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2    studying        photo
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2    studying        photo
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2    studying        photo
# ...                                     ...         ...          ...
# 22529  75d6b589-7fae-4a6d-b0d0-752845150e56  technology        audio
# 22530  75d6b589-7fae-4a6d-b0d0-752845150e56  technology        audio
# 22531  75d6b589-7fae-4a6d-b0d0-752845150e56  technology        audio
# 22532  75d6b589-7fae-4a6d-b0d0-752845150e56  technology        audio
# 22533  75d6b589-7fae-4a6d-b0d0-752845150e56  technology        audio
#
#              Type            Datetime Sentiment  Score     Month
# 0         disgust 2020-11-07 09:43:00  negative      0  November
# ...

# %%
cdf_1=FinalData_df.groupby("Month").agg(Max_score= ("Score", sum))
cdf_1 =cdf_1.reset_index()
cdf_1=cdf_1.sort_values(by="Max_score", ascending=False)
cdf_1
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15628\3914950702.py:1: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   cdf_1=FinalData_df.groupby("Month").agg(Max_score= ("Score", sum))
#         Month  Max_score
# 8         May      78972
# 4     January      76343
# 10    October      75969
# 9    November      75770
# 2    December      75623
# 5        July      75281
# 1      August      75227
# 11  September      73370
# 6        June      72964
# 7       March      72829
# 0       April      72141
# 3    February      68993

# %%
plt.plot(cdf_1['Month'],cdf_1['Max_score'],linewidth=2,marker='o')
plt.title('Month wise Views by Score')
plt.xlabel('Month')
plt.ylabel('Score')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %% [markdown]
# #### Analyse the Content According to the Best Months & Score:

# %%
hdf = FinalData_df.groupby(["Content Type", "Month"]).agg(Max_score=('Score','sum'))
hdf = hdf.reset_index()
hdf = hdf.sort_values(by="Max_score", ascending=False)
hdf
# Out:
#    Content Type      Month  Max_score
# 26        photo   December      21614
# 24        photo      April      21403
# 29        photo       July      21126
# 8           GIF        May      20740
# 28        photo    January      20642
# 37        video     August      20365
# 47        video  September      20337
# 30        photo       June      20180
# 44        video        May      20070
# 33        photo   November      20038
# 35        photo  September      19981
# 34        photo    October      19971
# 32        photo        May      19870
# 38        video   December      19677
# 10          GIF    October      19597
# 25        photo     August      19109
# 46        video    October      19045
# 9           GIF   November      19026
# 31        photo      March      18992
# 16        audio    January      18738
# 45        video   November      18702
# 41        video       July      18655
# 43        video      March      18622
# 6           GIF       June      18552
# ...

# %%
import seaborn as sns

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.barplot(x="Content Type", y="Max_score", hue="Month", data=hdf)
plt.xticks(rotation=45)
plt.title('Max Score by Content Type and Month')
plt.xlabel('Content Type')
plt.ylabel('Max Score')
plt.legend(title='Month')
plt.show()
